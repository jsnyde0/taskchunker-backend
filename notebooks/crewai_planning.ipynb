# %% [markdown]
# # Testing Agentic Planning with CrewAI

# %%
from datetime import datetime
from typing import List, Optional

from crewai import Agent, Crew, Task
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from pydantic import BaseModel, Field

load_dotenv()
# Out:
# True

# %%
# Create an OpenAI agent
chunker = Agent(
    role="Project Chunker",
    goal="Chunk a project into smaller tasks",
    backstory="You are a project planning expert using the Getting Things Done \
        (GTD) methodology. When given a project or task, chunk it down into a \
        hierarchical tree of subtasks.",
    verbose=True,
    allow_delegation=False,
    llm=ChatOpenAI(model="gpt-4o-mini"),
)


class ChunkedTask(BaseModel):
    id: str = Field(description="Unique identifier for the task")
    parent_id: Optional[str] = Field(
        None, description="ID of parent task, null if root"
    )
    title: str = Field(description="Short title/summary of the task")
    created_at: datetime = Field(default_factory=datetime.utcnow)


class TaskList(BaseModel):
    tasks: List["ChunkedTask"] = Field(default_factory=list)


# Create a simple task
chunk_task = Task(
    description="Chunk the {project} into smaller tasks. Create a \
                hierarchical task structure.",
    expected_output="A nested JSON object representing the hierarchical tree of \
    tasks and their subtasks",
    output_pydantic=TaskList,
    agent=chunker,
)

# Create and run the crew
crew = Crew(agents=[chunker], tasks=[chunk_task], verbose=True)

inputs = {"project": "Build a task chunker"}

result = crew.kickoff(inputs)
print("\nFinal Result:")
print(result)
# Out:
# Overriding of current TracerProvider is not allowed
# # Agent: Project Chunker
# ## Task: Chunk the Build a task chunker into a hierarchical tree of subtasks
#
#
# # Agent: Project Chunker
# ## Final Answer:
# {
#   "tasks": [
#     {
#       "task": "Define Project Goals",
#       "subtasks": [
#         {
#           "task": "Identify Purpose",
#           "subtasks": []
#         },
#         {
#           "task": "Set Success Criteria",
#           "subtasks": []
#         }
#       ]
#     },
#     {
#       "task": "Research Existing Solutions",
#       "subtasks": [
#         {
#           "task": "Analyze Competitors",
#           "subtasks": []
#         },
#         {
#           "task": "Study User Feedback",
#           "subtasks": []
#         }
#       ]
#     },
#     {
#       "task": "Design System Architecture",
#       "subtasks": [
#         {
#           "task": "Define Core Features",
#           "subtasks": [
#             {
#               "task": "User Input Handling",
#               "subtasks": []
#             },
#             {
#               "task": "Task Organization",
#               "subtasks": []
#             }
#           ]
#         },
#         {
#           "task": "Select Technology Stack",
#           "subtasks": [
#             {
#               "task": "Choose Programming Language",
#               "subtasks": []
#             },
#             {
#               "task": "Decide on Frameworks",
#               "subtasks": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "task": "Develop Prototype",
#       "subtasks": [
#         {
#           "task": "Set Up Development Environment",
#           "subtasks": []
#         },
#         {
#           "task": "Implement Core Functionality",
#           "subtasks": [
#             {
#               "task": "Create User Interface",
#               "subtasks": []
#             },
#             {
#               "task": "Build Backend Logic",
#               "subtasks": []
#             }
#           ]
#         }
#       ]
#     },
#     {
#       "task": "Conduct Testing",
#       "subtasks": [
#         {
#           "task": "Create Test Cases",
#           "subtasks": []
#         },
#         {
#           "task": "Perform User Testing",
#           "subtasks": []
#         }
#       ]
#     },
#     {
#       "task": "Gather Feedback",
#       "subtasks": [
#         {
#           "task": "Collect User Insights",
#           "subtasks": []
#         },
#         {
#           "task": "Analyze Feedback Data",
#           "subtasks": []
#         }
#       ]
#     },
#     {
#       "task": "Refine and Launch",
#       "subtasks": [
#         {
#           "task": "Make Necessary Adjustments",
#           "subtasks": []
#         },
#         {
#           "task": "Prepare for Launch",
#           "subtasks": []
#         }
#       ]
#     }
#   ]
# }
#
#
#
# Final Result:
# tasks=[ChunkedTask(id='1', parent_id=None, title='Define Project Goals', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='2', parent_id='1', title='Identify Purpose', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='3', parent_id='1', title='Set Success Criteria', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='4', parent_id=None, title='Research Existing Solutions', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='5', parent_id='4', title='Analyze Competitors', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='6', parent_id='4', title='Study User Feedback', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='7', parent_id=None, title='Design System Architecture', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='8', parent_id='7', title='Define Core Features', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='9', parent_id='8', title='User Input Handling', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='10', parent_id='8', title='Task Organization', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='11', parent_id='7', title='Select Technology Stack', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='12', parent_id='11', title='Choose Programming Language', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='13', parent_id='11', title='Decide on Frameworks', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='14', parent_id=None, title='Develop Prototype', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='15', parent_id='14', title='Set Up Development Environment', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='16', parent_id='14', title='Implement Core Functionality', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='17', parent_id='16', title='Create User Interface', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='18', parent_id='16', title='Build Backend Logic', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='19', parent_id=None, title='Conduct Testing', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='20', parent_id='19', title='Create Test Cases', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='21', parent_id='19', title='Perform User Testing', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='22', parent_id=None, title='Gather Feedback', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='23', parent_id='22', title='Collect User Insights', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='24', parent_id='22', title='Analyze Feedback Data', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='25', parent_id=None, title='Refine and Launch', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='26', parent_id='25', title='Make Necessary Adjustments', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719)), ChunkedTask(id='27', parent_id='25', title='Prepare for Launch', created_at=datetime.datetime(2025, 2, 11, 17, 3, 54, 344719))]
